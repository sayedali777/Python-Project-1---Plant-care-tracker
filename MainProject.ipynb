# %%
from P1 import *
from P2 import *
from P3 import *

# %%
load_plants()
# Out:
# Empty DataFrame
# Columns: [id, name, location, date_acquired, watering_frequency, sunlight, last_watered]
# Index: []

# %%
load_care_log()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 load_care_log()
#
# File ~/GA_DSB/labs_projects/labs_projects/projects/Python Project 1 - Plant care tracker/P2.py:9, in load_care_log()
#       5 def load_care_log():
#       6      """
#       7     this will read all the activities from the care_log csv
#       8      """
# ----> 9      care_log = pd.read_csv('.care_log.csv')
#      10      return care_log
#
# ...
