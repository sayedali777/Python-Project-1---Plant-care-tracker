# %%
from P1 import *
from P2 import *
from P3 import *

# %%
load_plants()
# Out:
# Empty DataFrame
# Columns: [id, name, location, date_acquired, watering_frequency, sunlight, last_watered]
# Index: []

# %%
load_care_log()
# Out:
# Empty DataFrame
# Columns: [plant_id, activity, dat]
# Index: []
